# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

from utils import modeling_utils, data_processing

# %reload_ext autoreload
# %autoreload 2

# %%
df_input = data_processing.get_data_year('../data/', 2022)
# Out:
# /home/quak/development/lol_stats/src/utils/data_processing.py:6: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path + file_name)

# %%
df = (
    df_input[
        (df_input['league']== 'LCK')
        # & 
    ]
)

# %%
df.groupby(['split', 'playoffs', 'teamname']).agg(
    total_wins=pd.NamedAgg('result', 'sum')
)
# Out:
#                                      total_wins
# split  playoffs teamname
# Spring 0        DRX                         132
#                 DWG KIA                     162
#                 Fredit BRION                126
#                 Gen.G                       168
#                 Hanwha Life Esports          72
#                 KT Rolster                  114
#                 Kwangdong Freecs            120
#                 Liiv SANDBOX                 66
#                 Nongshim RedForce            96
#                 T1                          216
#        1        DRX                          12
#                 DWG KIA                      30
#                 Fredit BRION                  0
#                 Gen.G                        24
#                 Kwangdong Freecs             18
#                 T1                           36
# Summer 0        DRX                         132
#                 DWG KIA                     144
#                 Fredit BRION                 66
#                 Gen.G                       210
#                 Hanwha Life Esports          72
#                 KT Rolster                  150
#                 Kwangdong Freecs             78
#                 Liiv SANDBOX                162
#                 Nongshim RedForce            84
#                 T1                          186
#        1        DRX                           6
#                 DWG KIA                      30
#                 Gen.G                        36
#                 KT Rolster                   12
#                 Liiv SANDBOX                 24
#                 T1                           18

# %%
with pd.option_context('display.max_columns', None):
    display(df.head(5))
# Out:
#                      gameid datacompleteness  url league  year   split
# 1440  ESPORTSTMNT01_2700815         complete  NaN    LCK  2022  Spring  \
# 1441  ESPORTSTMNT01_2700815         complete  NaN    LCK  2022  Spring
# 1442  ESPORTSTMNT01_2700815         complete  NaN    LCK  2022  Spring
# 1443  ESPORTSTMNT01_2700815         complete  NaN    LCK  2022  Spring
# 1444  ESPORTSTMNT01_2700815         complete  NaN    LCK  2022  Spring
#
#       playoffs                 date  game  patch  participantid  side
# 1440         0  2022-01-12 06:20:03     1  12.01              1  Blue  \
# 1441         0  2022-01-12 06:20:03     1  12.01              2  Blue
# 1442         0  2022-01-12 06:20:03     1  12.01              3  Blue
# 1443         0  2022-01-12 06:20:03     1  12.01              4  Blue
# 1444         0  2022-01-12 06:20:03     1  12.01              5  Blue
#
#      position playername                                   playerid teamname
# 1440      top     Kingen  oe:player:618a87d272773f68239d8ce5555f39d      DRX  \
# 1441      jng     Pyosik  oe:player:a2357eb17578485c2ba736db36cbc42      DRX
# 1442      mid       ZEKA  oe:player:54cfc6c3d11e0b534fd0958653bb240      DRX
# 1443      bot       Deft  oe:player:c588a2d07b69ca4ba61c96aebd3f793      DRX
# 1444      sup      BeryL  oe:player:dee54127bb56d2e2540ba71cc416f1c      DRX
#
#                                        teamid  champion   ban1     ban2
# 1440  oe:team:101f8589e58c724c1dcd5a9c1555277    Graves  Diana  Caitlyn  \
# 1441  oe:team:101f8589e58c724c1dcd5a9c1555277     Viego  Diana  Caitlyn
# 1442  oe:team:101f8589e58c724c1dcd5a9c1555277      Ryze  Diana  Caitlyn
# 1443  oe:team:101f8589e58c724c1dcd5a9c1555277  Aphelios  Diana  Caitlyn
# 1444  oe:team:101f8589e58c724c1dcd5a9c1555277      Sona  Diana  Caitlyn
#
#               ban3     ban4    ban5  gamelength  result  kills  deaths
# 1440  Twisted Fate  LeBlanc  Viktor        2195       0      0       5  \
# 1441  Twisted Fate  LeBlanc  Viktor        2195       0      1       3
# 1442  Twisted Fate  LeBlanc  Viktor        2195       0      0       2
# 1443  Twisted Fate  LeBlanc  Viktor        2195       0      3       2
# 1444  Twisted Fate  LeBlanc  Viktor        2195       0      1       2
#
#       assists  teamkills  teamdeaths  doublekills  triplekills  quadrakills
# 1440        1          5          14          0.0          0.0          0.0  \
# 1441        2          5          14          0.0          0.0          0.0
# 1442        0          5          14          0.0          0.0          0.0
# 1443        2          5          14          0.0          0.0          0.0
# 1444        4          5          14          0.0          0.0          0.0
#
#       pentakills  firstblood  firstbloodkill  firstbloodassist
# 1440         0.0         0.0             0.0               0.0  \
# 1441         0.0         0.0             0.0               0.0
# 1442         0.0         0.0             0.0               0.0
# 1443         0.0         1.0             1.0               0.0
# 1444         0.0         1.0             0.0               1.0
#
#       firstbloodvictim  team kpm    ckpm  firstdragon  dragons  opp_dragons
# 1440               0.0    0.1367  0.5194          NaN      NaN          NaN  \
# 1441               0.0    0.1367  0.5194          NaN      NaN          NaN
# 1442               0.0    0.1367  0.5194          NaN      NaN          NaN
# 1443               0.0    0.1367  0.5194          NaN      NaN          NaN
# 1444               0.0    0.1367  0.5194          NaN      NaN          NaN
#
#       elementaldrakes  opp_elementaldrakes  infernals  mountains  clouds
# 1440              NaN                  NaN        NaN        NaN     NaN  \
# 1441              NaN                  NaN        NaN        NaN     NaN
# 1442              NaN                  NaN        NaN        NaN     NaN
# 1443              NaN                  NaN        NaN        NaN     NaN
# 1444              NaN                  NaN        NaN        NaN     NaN
#
#       oceans  chemtechs  hextechs  dragons (type unknown)  elders  opp_elders
# 1440     NaN        NaN       NaN                     NaN     NaN         NaN  \
# 1441     NaN        NaN       NaN                     NaN     NaN         NaN
# 1442     NaN        NaN       NaN                     NaN     NaN         NaN
# 1443     NaN        NaN       NaN                     NaN     NaN         NaN
# 1444     NaN        NaN       NaN                     NaN     NaN         NaN
#
#       firstherald  heralds  opp_heralds  firstbaron  barons  opp_barons
# 1440          NaN      NaN          NaN         NaN     0.0         0.0  \
# 1441          NaN      NaN          NaN         NaN     0.0         2.0
# 1442          NaN      NaN          NaN         NaN     0.0         0.0
# 1443          NaN      NaN          NaN         NaN     0.0         0.0
# 1444          NaN      NaN          NaN         NaN     0.0         0.0
#
#       firsttower  towers  opp_towers  firstmidtower  firsttothreetowers
# 1440         NaN     NaN         NaN            NaN                 NaN  \
# 1441         NaN     NaN         NaN            NaN                 NaN
# 1442         NaN     NaN         NaN            NaN                 NaN
# 1443         NaN     NaN         NaN            NaN                 NaN
# 1444         NaN     NaN         NaN            NaN                 NaN
#
#       turretplates  opp_turretplates  inhibitors  opp_inhibitors
# 1440           NaN               NaN         0.0             1.0  \
# 1441           NaN               NaN         0.0             1.0
# 1442           NaN               NaN         0.0             0.0
# 1443           NaN               NaN         0.0             0.0
# 1444           NaN               NaN         0.0             0.0
#
#       damagetochampions       dpm  damageshare  damagetakenperminute
# 1440            18483.0  505.2301     0.369379              474.5877  \
# 1441             3799.0  103.8451     0.075922              640.0456
# 1442             7658.0  209.3303     0.153044              490.6879
# 1443            15003.0  410.1048     0.299832              302.7062
# 1444             5095.0  139.2711     0.101823              319.4897
#
#       damagemitigatedperminute  wardsplaced     wpm  wardskilled    wcpm
# 1440                  645.1298         11.0  0.3007          5.0  0.1367  \
# 1441                  568.0182         13.0  0.3554         15.0  0.4100
# 1442                  271.6811         19.0  0.5194          5.0  0.1367
# 1443                  462.9431         20.0  0.5467          8.0  0.2187
# 1444                  231.0888         64.0  1.7494         24.0  0.6560
#
#       controlwardsbought  visionscore    vspm  totalgold  earnedgold
# 1440                 9.0         35.0  0.9567      13189      8435.0  \
# 1441                13.0         58.0  1.5854      10792      6038.0
# 1442                 7.0         39.0  1.0661      14226      9472.0
# 1443                 5.0         58.0  1.5854      16249     11495.0
# 1444                21.0        115.0  3.1435       9291      4537.0
#
#       earned gpm  earnedgoldshare  goldspent  gspd  total cs  minionkills
# 1440    230.5695         0.210996    12875.0   NaN     315.0        270.0  \
# 1441    165.0478         0.151037    10375.0   NaN     178.0         27.0
# 1442    258.9157         0.236936    14075.0   NaN     351.0        304.0
# 1443    314.2141         0.287539    14825.0   NaN     352.0        314.0
# 1444    124.0182         0.113491     8375.0   NaN      36.0         30.0
#
#       monsterkills  monsterkillsownjungle  monsterkillsenemyjungle    cspm
# 1440          45.0                    NaN                      NaN  8.6105  \
# 1441         151.0                    NaN                      NaN  4.8656
# 1442          47.0                    NaN                      NaN  9.5945
# 1443          38.0                    NaN                      NaN  9.6219
# 1444           6.0                    NaN                      NaN  0.9841
#
#       goldat10  xpat10  csat10  opp_goldat10  opp_xpat10  opp_csat10
# 1440    3170.0  4619.0    83.0        3223.0      4640.0        89.0  \
# 1441    3075.0  3131.0    63.0        3036.0      3180.0        64.0
# 1442    3361.0  4914.0    92.0        3326.0      4770.0        91.0
# 1443    3259.0  3186.0    86.0        3092.0      3109.0        80.0
# 1444    2256.0  2720.0     6.0        2163.0      2467.0         0.0
#
#       golddiffat10  xpdiffat10  csdiffat10  killsat10  assistsat10
# 1440         -53.0       -21.0        -6.0        0.0          0.0  \
# 1441          39.0       -49.0        -1.0        0.0          0.0
# 1442          35.0       144.0         1.0        0.0          0.0
# 1443         167.0        77.0         6.0        0.0          0.0
# 1444          93.0       253.0         6.0        0.0          0.0
#
#       deathsat10  opp_killsat10  opp_assistsat10  opp_deathsat10  goldat15
# 1440         0.0            0.0              0.0             0.0    4763.0  \
# 1441         0.0            0.0              0.0             0.0    5107.0
# 1442         0.0            0.0              0.0             0.0    5589.0
# 1443         0.0            0.0              0.0             0.0    7171.0
# 1444         0.0            0.0              0.0             0.0    4568.0
#
#       xpat15  csat15  opp_goldat15  opp_xpat15  opp_csat15  golddiffat15
# 1440  6943.0   127.0        4965.0      7658.0       135.0        -202.0  \
# 1441  5355.0    89.0        4867.0      5626.0       104.0         240.0
# 1442  7592.0   144.0        5151.0      7796.0       151.0         438.0
# 1443  5691.0   140.0        4322.0      4431.0       116.0        2849.0
# 1444  4744.0    11.0        3136.0      3274.0         4.0        1432.0
#
#       xpdiffat15  csdiffat15  killsat15  assistsat15  deathsat15
# 1440      -715.0        -8.0        0.0          0.0         1.0  \
# 1441      -271.0       -15.0        1.0          2.0         0.0
# 1442      -204.0        -7.0        0.0          0.0         0.0
# 1443      1260.0        24.0        2.0          2.0         0.0
# 1444      1470.0         7.0        1.0          3.0         0.0
#
#       opp_killsat15  opp_assistsat15  opp_deathsat15
# 1440            0.0              1.0             0.0
# 1441            1.0              0.0             1.0
# 1442            0.0              0.0             0.0
# 1443            0.0              0.0             2.0
# 1444            0.0              0.0             1.0
